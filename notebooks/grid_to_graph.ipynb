# %%
import pandas as pd
import matplotlib.pyplot as plt

import os
import sys
sys.path.append(os.path.join(os.path.abspath(''), '..'))
from utils.graph import grid_to_graph, graph_to_grid

# %%
id = 'ff54343a-676b-4a45-a2fe-54a0e30383e9'
grid = pd.read_parquet(f'../data/{id}_grid.parquet').iloc[-1].to_numpy()
distribution = pd.read_parquet(f'../data/{id}_distribution.parquet').iloc[-1].to_numpy()

# %%
node_positions, edges, mask, input_nodes, target_nodes = grid_to_graph(grid.reshape(150, 150), distribution.reshape(150, 150))

# %%
node_positions.shape, edges.shape, mask.shape, input_nodes.shape, target_nodes.shape
# Out:
# ((2242, 2), (7566, 2), (2242, 1), (2242, 13), (2242, 1))

# %%
plt.imshow(graph_to_grid(node_positions, mask[:,-1]))
